# %%
import pandas as pd

# %%
df=pd.read_csv('adult.data')
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# 1. How many people of each race are represented in this dataset?

# %%
df.groupby('race')['race'].count()
# Out:
# race
#  Amer-Indian-Eskimo      311
#  Asian-Pac-Islander     1039
#  Black                  3124
#  Other                   271
#  White                 27816
# Name: race, dtype: int64

# %%
# 2. What is the average age of men?

# %%
df.age.mean()
# Out:
# 38.58164675532078

# %%
# 3. What is the percentage of people who have a Bachelor's degree?

# %%
edu_grp= df.groupby('education')['education'].count()
edu_grp
# Out:
# education
#  10th              933
#  11th             1175
#  12th              433
#  1st-4th           168
#  5th-6th           333
#  7th-8th           646
#  9th               514
#  Assoc-acdm       1067
#  Assoc-voc        1382
#  Bachelors        5355
#  Doctorate         413
#  HS-grad         10501
#  Masters          1723
#  Preschool          51
#  Prof-school       576
#  Some-college     7291
# Name: education, dtype: int64

# %%
bachelores_count= edu_grp.get(' Bachelors')
bachelores_count
# Out:
# 5355

# %%
total =  df.salary.count()
total
# Out:
# 32561

# %%
bachelores_percentage= (bachelores_count/total)*100
bachelores_percentage
# Out:
# 16.44605509658794

# %%
#4. What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?

# %%
adv_edu=[' Bachelors',' Masters',' Doctorate']

# %%
total_adv =df[(df['education'].isin(adv_edu))].shape[0]
total_adv
# Out:
# 7491

# %%
ppl_adv_edu = df[(df['education'].isin(adv_edu)) & (df['salary']==' >50K') ].shape[0]
ppl_adv_edu
# Out:
# 3486

# %%
per_ppl =(ppl_adv_edu/total_adv)*100
per_ppl
# Out:
# 46.535843011613935

# %%
#df2= (edu_grp.get(' Bachelors')| edu_grp.get(' Masters')| edu_grp.get(' Doctorate'))
#bmd=df2 & (df.salary==' >50K').count()
#bmd
# Out:
# 6143

# %%
#advanced_education_salry = (bmd/total) *100
#advanced_education_salry
# Out:
# 18.233469488037837

# %%
# 5. What percentage of people without advanced education make more than 50K?

# %%
ppl_without_adv_edu=df[~df['education'].isin(adv_edu)].shape[0]
ppl_without_adv_edu
# Out:
# 25070

# %%
ppl_without_adv_edu_50k = df[(~df['education'].isin(adv_edu)) & (df['salary']==' >50K')].shape[0]
ppl_without_adv_edu_50k
# Out:
# 4355

# %%
per_ppl_without_adv_edu_50k= (ppl_without_adv_edu_50k/ppl_without_adv_edu)*100
per_ppl_without_adv_edu_50k
# Out:
# 17.3713601914639

# %%
#6. What is the minimum number of hours a person works per week?

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
# 7. What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
count_m=df['hours-per-week'].min()
count_m
# Out:
# 1

# %%
count_min = (df['hours-per-week'] == df['hours-per-week'].min()).sum()
count_min
# Out:
# 20

# %%
min_50k =df[(df['hours-per-week']== count_m ) & (df['salary']==' >50K')].shape[0]
min_50k
# Out:
# 2

# %%
percentage_min_50k = (min_50k/ count_min)*100
percentage_min_50k
# Out:
# 10.0

# %%
# 8. What country has the highest percentage of people that earn >50K and what is that percentage?

# %%
country_count=df[df['salary']==' >50K']['native_country'].value_counts()
country_count
# Out:
# native_country
#  United-States         7171
#  ?                      146
#  Philippines             61
#  Germany                 44
#  India                   40
#  Canada                  39
#  Mexico                  33
#  England                 30
#  Italy                   25
#  Cuba                    25
#  Japan                   24
#  Taiwan                  20
#  China                   20
#  Iran                    18
#  South                   16
#  Puerto-Rico             12
#  Poland                  12
#  France                  12
#  Jamaica                 10
#  El-Salvador              9
#  Greece                   8
#  Cambodia                 7
#  Hong                     6
#  Yugoslavia               6
#  Ireland                  5
#  Vietnam                  5
#  Portugal                 4
#  Haiti                    4
#  Ecuador                  4
#  Thailand                 3
#  Hungary                  3
#  Guatemala                3
# ...

# %%
max_sal_count= country_count.max()
max_sal_count
# Out:
# 7171

# %%
sum_country_count=country_count.sum()
sum_country_count
# Out:
# 7841

# %%
per_country_count=(max_sal_count/sum_country_count)*100
per_country_count
# Out:
# 91.45517153424308

# %%
#9. Identify the most popular occupation for those who earn >50K in India.

# %%
india_50k=df[(df['native_country']==' India')& (df['salary'] == ' >50K')]
india_50k
# Out:
#        age          workclass  fnlwgt     education  education-num  \
# 11      30          State-gov  141297     Bachelors             13
# 968     48            Private  164966     Bachelors             13
# 1327    52            Private  168381       HS-grad              9
# 7258    42          State-gov  102343   Prof-school             15
# 7285    54          State-gov   93449       Masters             14
# 8124    36            Private  172104   Prof-school             15
# 9939    43        Federal-gov  325706   Prof-school             15
# 10590   35            Private   98283   Prof-school             15
# 10661   59            Private  122283   Prof-school             15
# 10736   30            Private  243190   Prof-school             15
# 11260   54            Private  225599       Masters             14
# 11384   34            Private   98283   Prof-school             15
# 13422   53            Private  366957     Bachelors             13
# ...

# %%
occ_india_50k =india_50k['occupation'].mode().values[0]
occ_india_50k
# Out:
# 0     Prof-specialty
# Name: occupation, dtype: object
